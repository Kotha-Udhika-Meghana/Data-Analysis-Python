# %% [markdown]
# # DAY 11
# ## Concepts
# - Intro to Matplotlib
#     + Image Reading and Slicing

# %% [markdown]
# ## Visualization
# - Matplotlib Library
# - Seaborn Library

# %% [markdown]
# ## 1.Matplotlib Library
# ### Introduction
# - Mostly used for 2D ploting
# - one of library in python
# - Used to create hignily qualitative graphs,plots,charts,etc...,
# ### For instalation  - pip install matplotlib
# ### Jhon D Hunter invented Matplotlib (released in year 2003)

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.2.2'

# %% [markdown]
# ## Pyplot
# - Pyplot is one of the popula module, which contains a collection of functions
# - It is easy user interface for constructing plots

# %%
import matplotlib.pyplot as plt

# %%
## Available methodes
print(dir(plt))
# Out:
# ['Annotation', 'Arrow', 'Artist', 'AutoLocator', 'Axes', 'Button', 'Circle', 'Figure', 'FigureCanvasBase', 'FixedFormatter', 'FixedLocator', 'FormatStrFormatter', 'Formatter', 'FuncFormatter', 'GridSpec', 'IndexLocator', 'Line2D', 'LinearLocator', 'Locator', 'LogFormatter', 'LogFormatterExponent', 'LogFormatterMathtext', 'LogLocator', 'MaxNLocator', 'MultipleLocator', 'Normalize', 'NullFormatter', 'NullLocator', 'Number', 'PolarAxes', 'Polygon', 'Rectangle', 'ScalarFormatter', 'Slider', 'Subplot', 'SubplotTool', 'Text', 'TickHelper', 'Widget', '_INSTALL_FIG_OBSERVER', '_IP_REGISTERED', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_auto_draw_if_interactive', '_backend_mod', '_get_running_interactive_framework', '_interactive_bk', '_log', '_pylab_helpers', '_setp', '_setup_pyplot_info_docstrings', '_show', 'acorr', 'angle_spectrum', 'annotate', 'arrow', 'autoscale', 'autumn', 'axes', 'axhline', 'axhspan', 'axis', 'axvline', 
# ...

# %% [markdown]
# ## Image Reading and Slicing

# %%
## Image reading
img = plt.imread('logo.jpg')
img
# Out:
# array([[[  0,  95, 163],
#         [  0,  95, 163],
#         [  0,  95, 163],
#         ...,
#         [  0, 118, 164],
#         [  1, 117, 164],
#         [  2, 117, 164]],
#
#        [[  0,  95, 163],
#         [  0,  95, 163],
#         [  0,  95, 163],
#         ...,
#         [  0, 118, 164],
#         [  1, 117, 164],
#         [  2, 117, 164]],
#
#        [[  0,  95, 163],
#         [  0,  95, 163],
#         [  0,  95, 163],
#         ...,
#         [  0, 118, 164],
#         [  1, 117, 164],
#         [  2, 117, 164]],
#
#        ...,
#
#        [[  1,  62, 117],
#         [  1,  62, 117],
#         [  1,  62, 117],
#         ...,
#         [  2,  63, 118],
#         [  2,  63, 118],
#         [  2,  63, 118]],
#
#        [[  1,  62, 117],
#         [  1,  62, 117],
#         [  1,  62, 117],
#         ...,
#         [  2,  63, 118],
#         [  2,  63, 118],
#         [  2,  63, 118]],
#
#        [[  1,  62, 117],
#         [  1,  62, 117],
#         [  1,  62, 117],
# ...

# %%
## Display image
plt.imshow(img)

# %%
plt.imshow(img[130:250, 310:450])

# %%
plt.imshow(img[130:300, 310:500])
## plt.imshow(img[y-axis, x-axis])
